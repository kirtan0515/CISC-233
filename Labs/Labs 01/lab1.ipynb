# %% [markdown]
# **Lab 1: Comparative Analysis and Enhancement of Sorting Algorithms**
#
# In this lab, we will cover sorting algorithms, specifically focusing on two classic algorithms: Bubble Sort and Insertion Sort. Our goal is to analyze and compare the performance of these algorithms in terms of the number of steps and swaps required to sort a given dataset.
#
# **Objectives:**
#
# Understand the basic concepts behind Bubble Sort and Insertion Sort.
#
# 1.   Implement and analyze the algorithms, counting the number of steps and swaps.
# 2.   Investigate the input sensitivity of each algorithm.
# 3.  Propose and implement optimizations to enhance algorithm efficiency.
# 4.  Compare the performance of the optimized algorithms.
#
# **Sorting Algorithms:**
#
# ***Bubble Sort:***
#
# Bubble Sort is a simple comparison-based sorting algorithm that repeatedly steps through the list, compares adjacent elements, and swaps them if they are in the wrong order. It continues until the entire list is sorted.
#
# ***Insertion Sort:***
#
# Insertion Sort is another elementary sorting algorithm that builds the final sorted array one item at a time. It is much less efficient on large lists than more advanced algorithms such as quicksort, heapsort, or merge sort.

# %%
import random;
random_numbers = [random.randint(0, 10000000) for _ in range(100000)]
sorted_numbers = list(range(100000))
reversed_sorted_numbers = sorted_numbers[::-1]
my_list = [9, 8, 7, 6, 5, 4, 3, 2, 1]
random.shuffle(my_list)
print(my_list)
# Out:
# [9, 7, 4, 2, 3, 1, 5, 8, 6]

# %% [markdown]
# **TASK 1: Understanding the Algorithms:** (5 points)
#
# - Provide a comprehensive overview of Bubble Sort and Insertion Sort, including:
#
#   - Introduction: Briefly explain the fundamental principles of Bubble Sort and Insertion Sort.
#   - Operational Mechanism: Describe how each algorithm operates, particularly focusing on how they iterate through the elements and make comparisons and swaps.
#
# - Discuss the time complexity of Bubble Sort and Insertion Sort, considering their performance in best, average, and worst-case scenarios.

# %% [markdown]
# **TASK 2: Analyzing Bubble Sort:** (10 points)
# - Implement and analyze Bubble Sort, focusing on steps and swaps.
# - Use `random_numbers, sorted_numbers, reversed_sorted, my_list` examine the algorithm's behavior on different inputs.

# %%
# Test case (Example)
def bubble_sort(arr):
  pass

sorted_list, steps, swaps = bubble_sort(random_numbers)

print("Original List:", random_numbers)
print("Sorted List:", sorted_list)
print("Steps:", steps)
print("Swaps:", swaps)

# %% [markdown]
# **TASK 3: Analyzing Insertion Sort:** (10 points)
#
# - Implement and analyze Insertion Sort with a focus on steps and swaps.
# - Use `random_numbers, sorted_numbers, reversed_sorted, my_list `examine the algorithm's behavior on different inputs.

# %%
# Test case (Example)
def insertion_sort(arr):
  pass

sorted_list, steps, swaps = insertion_sort(random_numbers)

print("Original List:", random_numbers)
print("Sorted List:", sorted_list)
print("Steps:", steps)
print("Swaps:", swaps)

# %% [markdown]
# **TASK 4: Input Sensitivity:** (15 points)
#
# Utilize a random number generator to conduct an empirical analysis and plot a diagram comparing the performance of Bubble Sort and Insertion Sort as the size of input elements (n) increases. Focus on the relationship between the number of steps each algorithm takes and the varying sizes of input arrays. Provide insights into how the algorithms perform in terms of computational complexity with increasing input size

# %%
import matplotlib.pyplot as plt

a = []
b = []
for i in range(10000):
    a.append(2 * i * i)
    b.append(2.5 * i * i)

# Plotting
plt.plot(a, label='Algorithm 1')
plt.plot(b, label='Algorithm 2')

# Adding labels and title
plt.xlabel('n')
plt.ylabel('steps')
plt.title('Steps vs. Number of elements')

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# **TASK 5: Comparative Study:** (5 points)
#
# - Develop a comprehensive comparison of Bubble Sort and Insertion Sort.
# - Discuss trade-offs and scenarios where one may be preferred over the other.
# - Introduce some ideas to improve the performance of these two algorithms.

# %% [markdown]
# **TASK 6: Conclusion:** (5 points)
#
# Summarize key findings and insights from the lab.
